# %%
import pandas as pd
import csv
import sys
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as md

# %%
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
csv.field_size_limit(100000000)
# Out:
# 9223372036854775807

# %%
commlst = []
with open('comments_de.csv', newline='') as csvfile:
    ids = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in ids:
        commlst.append(','.join(row))

# %%
commlst[0]
# Out:
# 'How did Bill Gates made his BILLIONS  ?????,"He has NO medical degree  NO science degree / a chip '

# %%
analyser = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Demonstrative Function
# Vader works for English as well as for German texts. Keep in mind tho, that it just uses machine translation to English. Still in terms of sentiment analysis, this shouldn't be problematic.

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score

# %%
sentiment_analyzer_scores(commlst[5036])
# Out:
# In fact, this is y we have so few female leaders.  They are not often degenerates that rape, kill and torture others for personal gain. {'neg': 0.353, 'neu': 0.557, 'pos': 0.09, 'compound': -0.8979}

# %%
score = analyser.polarity_scores(commlst[1])

# %%
score['neg']
# Out:
# 0.0

# %% [markdown]
# ### Usage on videos
# Oh and hey - good news. We can also use the same tool for the transcripts of our videos.

# %%
vidTexts = pd.read_csv('../DataRetrieval/video_texts.csv')

# %%
vidlst = pd.read_csv('../DataRetrieval/videos_more_info.csv')

# %%
idlst = pd.read_csv('../DataRetrieval/idlst.csv')

# %%
vidTexts = vidTexts.drop('Unnamed: 0', axis=1)

# %%
vidlst = vidlst.drop('Unnamed: 0', axis = 1)

# %%
vidTexts = vidTexts.rename(columns={'vidID':'Video Id'})

# %%
len(vidTexts)
# Out:
# 536

# %%
len(vidlst)
# Out:
# 540

# %%
video_df = vidTexts.merge(vidlst, on = 'Video Id', how = 'left')

# %%
video_df.loc[:,'lViews'] = np.log(video_df['Views'])
# Out:
# /home/lukas/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
video_df['Comments Count tool'] = np.sqrt(video_df['Comments Count']+1.2)
# Out:
# /home/lukas/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
video_df
# Out:
#      Unnamed: 0     Video Id  \
# 0             0  Jl3gnP4uG2o
# 1             1  BX1_2j-QQuk
# 2             2  XJn_4cPT6nE
# 3             3  OAx_6-wdslM
# 4             4  gTjXTRz4dDw
# 5             5  _0QdI0rVoHA
# 6             6  bIuhCUxpPsQ
# 7             7  aVtD0swv94c
# 8             8  zwGdnCNi8Ss
# 10           10  ogMEpsGh9Yo
# 11           11  xtY4ThJ9i9E
# 12           12  3tCUWbhyiig
# 13           13  pQocN_c2uLI
# 14           14  OzsjvQAk-eA
# 15           15  6usVX6BJYEk
# 17           17  SWvcwYsMDew
# 18           18  p0pgrq-DXCY
# 19           19  vqqVbU0nkOE
# 20           20  zmtxU8q6ohA
# 21           21  id1ryXAgygE
# 22           22  WOtu1S6xiAo
# 23           23  LaAPJdO3dgA
# 24           24  r9r4c1d8kSw
# 25           25  jiUKpX09zo4
# 26           26  ug1pb8rkI0s
# 29           29  ZpbHJs1JHV8
# 30           30  TpqdERCZrSU
# 31           31  2CC5ejfjFq4
# 32           32  7DmpncBDibA
# 33           33  bRD4BGec0wU
# ..          ...          ...
# 504         504  0__6kx-vTO4
# 505         505  dj7Mrk9PL-g
# 506         506  cSPlsSZk-e4
# 507         507  1rlp6bAZLtU
# 508         508  1f-iRuLV4mY
# 509         509  ITuw1a-i_Qs
# 510         510  WOoJh6oYAXE
# 511         511  6XFwlNVRD5M
# 512         512  nJec6SUP_iM
# 513         513  vJYweyRixUs
# 514         514  efnHiz0USQE
# 515         515  1jsXwm9wZwE
# 516         516  WR6uSXW-8p4
# 517         517  m2Ux2PnJe6E
# 518         518  uVFI7pZzNAY
# 519         519  5fyMtBmvym8
# 520         520  zPx5N6Lh3sw
# 521         521  -W7ZfpHbWZM
# 522         522  kw_acqrMSk8
# 523         523  L7JRqspJStQ
# 524         524  YEbQgKIXWVc
# 525         525  MoykduZa4Y0
# 526         526  5uooRe07mYM
# 527         527  Plf7fQ-cmz8
# 529         529  dNiuaKKEPu8
# 530         530  oh29ZxZrH_I
# 531         531  VoQo1jqGr80
# 532         532  VQSM7EVCFbY
# 533         533  cBHJ-8Bch4E
# 535         535  tmk0VpSwUcs
#
#                                                vidText  Category  \
# 0    Transcriber: Marcia de Brito\nReviewer: Ariana...      27.0
# 1    Bonjour. Je suis Bill Gates, le président de M...      22.0
# 2    It's important to me to connect with the\npeop...      25.0
# 3    [music] Everywhere you look, computers are cha...      27.0
# 4    For a good read this summer, try these five\nb...      25.0
# 5    Hi everyone, it's Jerry. Ever since Magnus Car...      27.0
# 6    UPDATE FOR YOU ON EYEWITNESS NEWS AT SIX. (MM)...      25.0
# 7    (Image source: Wikimedia Commons / Kees de\nVo...      28.0
# 8    Da Vinci lived from 1452 to 1519, so it’s the ...      29.0
# 10   ON ON IMPEACHMENT ON IMPEACHMENT INQUIRY. ON I...      25.0
# 11   In any fight, it’s important to know your\nene...      28.0
# 12   Microsoft-cofounder Bill Gates is increasing\n...      29.0
# 13   The personal computer is one of the greatest\n...      27.0
# 14   Do people really want to be in a\nmicrocosm wh...      22.0
# 15   We’d bet that the vast majority of people\nrea...      27.0
# 17   �Mass Sterilization�: Kenyan Doctors Find\nAnt...      25.0
# 18   10 Advice by Bill Gates to Young People Who\nW...      27.0
# 19   We've all heard of Bill Gates he's the\ninvent...      27.0
# 20   We live in a time of extraordinary inequality....      24.0
# 21   5 главных правил, которыми пользуются многие п...      22.0
# 22   My name is Mandy Manning. And I teach English ...      29.0
# 23   Let's talk about vaccination a little bit. We'...      25.0
# 24   - Crown Prince Mohammed bin Salman is a new ge...      25.0
# 25   Well, this is about state budgets. This is pro...      27.0
# 26   Mnoho lidí je velmi optimistických ohledně vět...      22.0
# 29   so that there is no misunderstanding please al...      25.0
# 30   Microsoft&nbsp;co-founder Bill Gates' physical...      28.0
# 31   I mean, Bill, one of the the riddles about\nth...      25.0
# 32   In our annual letter this year, Melinda and I ...      29.0
# 33   to nie ja - bill gates hit ler   nie wiedizal ...      22.0
# ..                                                 ...       ...
# 504  Well, let's talk about climate change. Now, pe...      29.0
# 505    AOA welcome to urduscore24 I am Salman Ahmed...      25.0
# 506  Merhaba. Coronavirüsün geçen haftaya göre bir ...      25.0
# 507  Tiens, tiens, tiens... Bill Gates... Qu'est ce...      27.0
# 508  In the two years I've gotten to know Bill, I'v...       1.0
# 509  well it's hard to say uh you know obviously th...      27.0
# 510  Richard Feynman was an incredible scientist. H...      29.0
# 511  Well, here it is. This is it. The Nebraska Fur...      29.0
# 512  [INTRO PLAYING] Seventy years ago, I was in hi...      17.0
# 513              Please See Description Box For Proofs      25.0
# 514  Imagine what it's like to live in extreme\npov...      29.0
# 515                                                  .      26.0
# 516  The record-number of fires burning\nacross Bra...      25.0
# 517  people make decisions every day for\nexample b...      24.0
# 518  Hi,  I'm Marc Gielissen,  please subscribe and...      27.0
# 519  A man who is known in history for Windows,\nbu...      27.0
# 520  Our next speaker, first known as the entrepren...      27.0
# 521  'We vertrouwen dit model niet. \nDe code is on...      29.0
# 522  Our foundation got very involved in efforts to...      25.0
# 523  FAMILY, FAMILY, MELINDA'S FAMILY, MELINDA'S NE...      25.0
# 524  I got the microchip. Christina S. is happy. Sh...      24.0
# 525  Hey, everyone. Stefan here from projectlife ma...      27.0
# 526  Hans Rosling spent his life not only\nundersta...      29.0
# 527                                               None      22.0
# 529  ♪\n♪ &gt;&gt; Stephen: WELCOME BACK,\nEVERYBOD...      24.0
# 530  In my work on global health I'm often\nreminde...      28.0
# 531  Bill Gates, Founder &amp; CEO of Microsoft Sai...      27.0
# 532  Zece miliarde de dolari. Adica, vorbeste doar ...       1.0
# 533  [APPLAUSE] So Bill, thank you very\nmuch for d...      27.0
# 535   \nTHOSE ISSUES MORE. GATES, NIC O. THOSE ISSU...      25.0
#
#                    Channel Id  \
# 0    UCsT0YIqwnpJCM-mx7-gSA4Q
# 1    UCp2rcO8R6UkBSLs6NjCp-Cw
# 2    UCZKASNi4Nm27rw3gfUIjEKA
# 3    UCJyEBMU1xVP2be1-AoGS1BA
# 4    UCnEiGCE13SUI7ZvojTAVBKw
# 5    UCCDOQrpqLqKVcTCKzqarxLg
# 6    UCnwI-VN5jXWIGQKOI9PMDMw
# 7    UCB0QyTJ3lQUDmE0yZqiuQuA
# 8    UCnEiGCE13SUI7ZvojTAVBKw
# 10   UCp1KrVaZDZ7BOI_QBuTWWmg
# 11   UCnEiGCE13SUI7ZvojTAVBKw
# 12   UCyhpw4-Etc79Sq77Swre5KA
# 13   UC_E4px0RST-qFwXLJWBav8Q
# 14   UC9f78Z5hgtDt0n8JWyfBk8Q
# 15   UC64UiPJwM_e9AqAd7RiD7JA
# 17   UC8PY4o5sTc1iCGIlSX4f15g
# 18   UC4IhgQSETRnAIEb694TwQxQ
# 19   UC3amebly_98Ne_-kH1ADQxQ
# 17                                            Shakaama           534.0
# 18                                  Success Secrets TV           546.0
# 19                                     Betterment Boss             6.0
# 20                              Free To Choose Network             8.0
# 21                                 Motivation Get rich            11.0
# 22                                          Bill Gates           103.0
# 23                                   David Pakman Show          1054.0
# 24                                    Business Insider            82.0
# 25                                                 TED           466.0
# 26                                         Hnutí ducha             0.0
# 29                                             info KU             9.0
# 30                                THE FUTURE REVEALED!           252.0
# 31                                          André Levy             4.0
# 32                                          Bill Gates            84.0
# 33                                        berk yrk yke             2.0
# ..                                                 ...             ...
# 504                                         Bill Gates          3559.0
# 505                                       Urdu Score24             0.0
# 506                                  Boşlukları Doldur           260.0
# 507                                         Eric Greco            14.0
# 508                                      Project: Film             6.0
# 509                                 Harvard University             0.0
# 510                                         Bill Gates          1381.0
# 511                                         Bill Gates          2503.0
# 512                                      HNMotivations             0.0
# 513                                          Real Face           194.0
# 514                                         Bill Gates          6740.0
# 515                      YOUNG GEN MOTIVATIONAL VIDEOS             0.0
# 516                                               CNBC          2324.0
# 517                                           Code.org           250.0
# 518                            Marc Gielissen - Author            23.0
# 519  Educational Videos for Students (Cartoons on B...             2.0
# 520                                 Harvard University             0.0
# 521                               Stichting Vaccinvrij            11.0
# 522                                                Mic             0.0
# 523                                             KING 5             2.0
# 524                           Bohemian Browser Ballett           706.0
# 525                               Project Life Mastery            55.0
# 526                                         Bill Gates           265.0
# 527                                   Corporate Valley             3.0
# 529                 The Late Show with Stephen Colbert          4815.0
# 530                                       AmyrisVideos            53.0
# 531                    YaaNa - Inspiration & Knowledge            22.0
# 532                                    Crestin Ortodox             0.0
# 533                                 Harvard University             0.0
# 535                                                CNN           803.0
#
#      Dislikes Count  Likes Count Published Day         ...           \
# 0               8.0        162.0    2012-02-21         ...
# 1              11.0        357.0    2020-06-03         ...
# 2               1.0          3.0    2019-01-11         ...
# 3             165.0       4083.0    2018-01-30         ...
# 4             294.0      25111.0    2019-05-20         ...
# 5            3757.0      25313.0    2014-01-24         ...
# 6               0.0          1.0    2017-11-17         ...
# 7              10.0         31.0    2013-08-10         ...
# 8              99.0       7496.0    2018-12-18         ...
# 10            281.0        265.0    2019-09-25         ...
# 11           3683.0       5321.0    2020-05-12         ...
# 12              3.0         28.0    2011-02-02         ...
# 13            567.0      19730.0    2018-03-31         ...
# 14             18.0        155.0    2018-01-30         ...
# 15            800.0      13184.0    2017-12-15         ...
# 17            105.0       1461.0    2015-02-19         ...
# 18            659.0      31705.0    2018-09-02         ...
# 19             17.0         71.0    2019-04-17         ...
# 20              5.0        147.0    2017-06-14         ...
# 21              1.0          4.0    2020-05-30         ...
# 22             26.0        978.0    2018-08-21         ...
# 23             98.0       1327.0    2020-04-16         ...
# 24             72.0        403.0    2018-04-11         ...
# 25             98.0       1484.0    2011-03-05         ...
# 26              0.0          1.0    2020-04-02         ...
# 29              0.0          7.0    2020-05-05         ...
# 30            153.0        815.0    2017-11-04         ...
# 31              2.0          3.0    2020-03-31         ...
# 32             48.0        975.0    2015-01-21         ...
# 33              0.0          2.0    2020-05-31         ...
# ..              ...          ...           ...         ...
# 504           403.0      27965.0    2019-02-12         ...
# 505             0.0          3.0    2020-04-05         ...
# 506           139.0       3110.0    2020-02-19         ...
# 507             1.0         25.0    2020-05-02         ...
# 508             4.0         86.0    2019-10-28         ...
# 509             4.0         14.0    2010-10-08         ...
# 510           877.0      81891.0    2016-01-27         ...
# 511          1319.0      49879.0    2017-06-06         ...
# 512             0.0          2.0    2020-04-27         ...
# 513            37.0        906.0    2017-10-27         ...
# 514         14628.0      27974.0    2018-10-31         ...
# 515             0.0          4.0    2017-12-15         ...
# 516           948.0       4803.0    2019-09-07         ...
# 517           326.0      11403.0    2013-12-09         ...
# 518             3.0        110.0    2020-04-14         ...
# 519            12.0         38.0    2019-04-04         ...
# 520          1075.0      21377.0    2013-05-20         ...
# 521             1.0         63.0    2020-04-08         ...
# 522           170.0         41.0    2017-02-14         ...
# 523             8.0          8.0    2019-05-22         ...
# 524           449.0       6697.0    2020-05-19         ...
# 525            41.0       1148.0    2016-10-13         ...
# 526            54.0       4142.0    2018-04-03         ...
# 527             1.0         25.0    2013-05-08         ...
# 529          2987.0      12781.0    2020-04-24         ...
# 530            25.0         57.0    2013-05-03         ...
# 531             0.0         15.0    2020-03-30         ...
# 532             0.0          2.0    2020-05-11         ...
# 533           743.0       4114.0    2013-09-24         ...
# 535           401.0       1766.0    2018-02-18         ...
#
#                                            Video Title      Views  \
# 0    Beethoven as Bill Gates - Jose Bowen at TEDxSM...    38080.0
# 1    Partie 1 - Comment Bill Gates monopolise la sa...     6621.0
# 2                    Chairman Bill Gates' Coffee Habit      357.0
# 3                       Introducing How Computers Work   532795.0
# 4                          5 books to read this summer   539436.0
# 5    How Magnus Carlsen checkmated Bill Gates in 9 ...  5028970.0
# 6    Doctor: Bill Gates donation could have huge im...       79.0
# 7    Bill Gates Isn't Too Happy with Google's Proje...     6553.0
# 8    Leonardo da Vinci’s Notebook: The Codex Leicester   264809.0
# 10   Bill & Melinda Gates Foundation under fire ove...    35504.0
# 11                  Scanning for answers to a pandemic   142677.0
# 12   Bill Gates adds $100m, as Polio nears eradication     4444.0
# 13          The Xerox Thieves: Steve Jobs & Bill Gates   996859.0
# 14         Bill Gates on the good news about fake news    10519.0
# 15    What Does Bill Gates Carry Around in His Wallet?   709269.0
# 17   Kenyan Bishops Discover Mass Sterilization in ...   137864.0
# 18   Bill Gates' Advice for Young People Who Want t...   930006.0
# 19   How To Be As Productive As Bill Gates - 5 Prov...     6735.0
# 20   Dead Wrong® with Johan Norberg - How Much Rich...     3164.0
# 21   How To Repeat The Success of Bill Gates in 6 m...       22.0
# 22     Bill Gates’s Heroes in the Field: Mandy Manning    38884.0
# 23   Lunatic Trumpists Will REFUSE "Bill Gates Vacc...    23106.0
# 24   Why Saudi's Crown Prince Just Met With Trump, ...    30241.0
# 25   How state budgets are breaking US schools | Bi...   159751.0
# 26              Bill Gates slams wind and solar energy       21.0
# 29   BILL GATES PROTES AMERIKA...!!! Amerika kalah ...       72.0
# 30   🔵THE REAL BILL GATES PREDICTIONS FOR 2018 - 20...   121391.0
# 31   Bill Gates' message on #COVID19 to the souther...      149.0
# 32                   Bill & Melinda Gates: Our Big Bet    96677.0
# 33   SIEĆ 5G ,Bill Gates i REPTILIANIE HAKUJĄ MI KONTO       20.0
# ..                                                 ...        ...
# 504             The grand challenges of climate change   805546.0
# 505  Bill Gates About Viral Infection | Bill Gates ...       65.0
# 506  Bize Yalan Söylediler - Bekçi Maaşları, İdlib,...   162718.0
# 507                       Bill Gates - Mini Biographie      223.0
# 508  Inside Bill's Brain | Ending Scene Decoding Bi...     3788.0
# 509                        Bill Gates Green Technology     7213.0
# 510                       The Best Teacher I Never Had  2153695.0
# 511             Testing Mattresses with Warren Buffett  2381351.0
# 512  Bill Gates & Warren Buffett - DO IT RIGHT NOW ...       44.0
# 513  Illuminati & Modern Medicine | Bill Gates Depo...    35968.0
# 514                          Living in extreme poverty   632277.0
# 515  Bill Gates Inspirational Quotes| Top10 Motivat...      483.0
# 516  Why Bill Gates Is Funding Solar Geoengineering...   270158.0
# 517   Hour of Code - Bill Gates explains If statements   973836.0
# 518       Bill Gates - The Vaccine Guru with a mission     5615.0
# 519  Is Bill Gates the richest person in the world?...     2887.0
# 520       Bill Gates Harvard Commencement Address 2007  2426421.0
# 521          The HighWire: Over Ferguson en Bill Gates     1879.0
# 522  What Bill Gates learned after meeting with sex...     4711.0
# 523  Bill Gates talks 1-on-1 about ending polio, dr...      695.0
# 524      Frisch geimpft: Leben mit dem Bill-Gates-Chip   104621.0
# 525  Success Habits of Billionaires: Warren Buffett...    41451.0
# 526                          Bill Gates on Factfulness   207795.0
# 527  Bill Gates Exclusive Interview - Chairman of M...     3316.0
# 529  Bill Gates: Global Innovation Is The Key To Ac...   994448.0
# 530                  Bill Gates on Artemisinin Project    14388.0
# 531  Bill Gates Predicted a Pandemic like the Coron...      239.0
# 532            Bill Gates' Plan to Vaccinate the World       30.0
# 533  William H. Gates III COL '77, LLD '07 Q&A | Th...   987515.0
# 535       Why Bill Gates is optimistic about the world   198739.0
#
#     vader_neg_prp vader_pos_prp vader_neut_prp  vader_compound  \
# 0           0.033         0.072          0.895           0.072
# 1           0.011         0.015          0.974           0.015
# 2           0.017         0.172          0.810           0.172
# 3           0.000         0.025          0.975           0.025
# 4           0.089         0.246          0.665           0.246
# 5           0.052         0.140          0.807           0.140
# 6           0.038         0.069          0.893           0.069
# 7           0.050         0.127          0.823           0.127
# 8           0.031         0.091          0.878           0.091
# 10          0.087         0.168          0.745           0.168
# 11          0.049         0.087          0.864           0.087
# 12          0.062         0.056          0.883           0.056
# 13          0.037         0.121          0.842           0.121
# 14          0.051         0.131          0.818           0.131
# 20         2017-06-14  1497398400000000000   8.059592             3.000000
# 21         2020-05-30  1590796800000000000   3.091042             3.464102
# 22         2018-08-21  1534809600000000000  10.568338            10.198039
# 23         2020-04-16  1586995200000000000  10.047848            32.480764
# 24         2018-04-11  1523404800000000000  10.316954             9.110434
# 25         2011-03-05  1299283200000000000  11.981372            21.610183
# 26         2020-04-02  1585785600000000000   3.044522             1.000000
# 29         2020-05-05  1588636800000000000   4.276666             3.162278
# 30         2017-11-04  1509753600000000000  11.706772            15.905974
# 31         2020-03-31  1585612800000000000   5.003946             2.236068
# 32         2015-01-21  1421798400000000000  11.479131             9.219544
# 33         2020-05-31  1590883200000000000   2.995732             1.732051
# ..                ...                  ...        ...                  ...
# 504        2019-02-12  1549929600000000000  13.599276            59.665736
# 505        2020-04-05  1586044800000000000   4.174387             1.000000
# 506        2020-02-19  1582070400000000000  11.999774            16.155494
# 507        2020-05-02  1588377600000000000   5.407172             3.872983
# 508        2019-10-28  1572220800000000000   8.239593             2.645751
# 509        2010-10-08  1286496000000000000   8.883640             1.000000
# 510        2016-01-27  1453852800000000000  14.582696            37.175261
# 511        2017-06-06  1496707200000000000  14.683179            50.039984
# 512        2020-04-27  1587945600000000000   3.784190             1.000000
# 513        2017-10-27  1509062400000000000  10.490385            13.964240
# 514        2018-10-31  1540944000000000000  13.357083            82.103593
# 515        2017-12-15  1513296000000000000   6.180017             1.000000
# 516        2019-09-07  1567814400000000000  12.506762            48.218254
# 517        2013-12-09  1386547200000000000  13.788998            15.842980
# 518        2020-04-14  1586822400000000000   8.633197             4.898979
# 519        2019-04-04  1554336000000000000   7.967973             1.732051
# 520        2013-05-20  1369008000000000000  14.701928             1.000000
# 521        2020-04-08  1586304000000000000   7.538495             3.464102
# 522        2017-02-14  1487030400000000000   8.457655             1.000000
# 523        2019-05-22  1558483200000000000   6.543912             1.732051
# 524        2020-05-19  1589846400000000000  11.558100            26.589472
# 525        2016-10-13  1476316800000000000  10.632267             7.483315
# 526        2018-04-03  1522713600000000000  12.244307            16.309506
# 527        2013-05-08  1367971200000000000   8.106515             2.000000
# 529        2020-04-24  1587686400000000000  13.809943            69.397406
# 530        2013-05-03  1367539200000000000   9.574150             7.348469
# 531        2020-03-30  1585526400000000000   5.476464             4.795832
# 532        2020-05-11  1589155200000000000   3.401197             1.000000
# 533        2013-09-24  1379980800000000000  13.802947             1.000000
# 535        2018-02-18  1518912000000000000  12.199748            28.354894
#
# [465 rows x 24 columns]

# %%
now = datetime.datetime.now()

# %%
print(now)
# Out:
# 2020-06-18 11:35:02.966128

# %%
scorelst = []
for i in range(len(video_df)):
    scorelst.append(sentiment_analyzer_scores(video_df['vidText'][i]))

# %%
video_df['Published Day TS'] = [pd.Timestamp(i) for i in video_df['Published Day']]
# Out:
# /home/lukas/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
video_df['Published Day Num'] = video_df['Published Day TS'].astype(np.int64)
# Out:
# /home/lukas/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
video_df = video_df.dropna(subset = ['Channel Id'])

# %%
max(video_df['Comments Count tool'])
# Out:
# 677.039142147631

# %%
import matplotlib.dates as mdate
import numpy as np
import datetime as dt

# %%
dates = [pd.to_datetime(d) for d in video_df['Published Day']]

# %%
plt.figure(figsize=(15,10))
ax.set_title('Sentiment of Videos over time and comment-interaction', fontsize = 25)
plt.scatter(dates, video_df['lViews'], s=video_df['Comments Count tool'], c= video_df['vader_compound'])
plt.colorbar()

plt.show()

# %%
plt.figure(figsize=(15,10))

sns.set(style="darkgrid")
plt.scatter(x=video_df['Published Day Num'], y=video_df['lViews'], c = video_df['vader_compound'], s= video_df['Comments Count tool'])
#plt.xticks(video_df['Published Day Num'].astype(datetime.datetime))
plt.colorbar()

plt.show()

# %%
plt.figure(figsize=(15,10))
sns.set(style="darkgrid")
ax1 = video_df.plot.scatter(x='Published Day Num', y='lViews', c = 'vader_compound', s= 'Comments Count tool', figsize = (15,10))
#ax.set_xticklabels([datetime.fromtimestamp(ts / 1e9).strftime('%H:%M:%S') for ts in ax.get_xticks()])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-bf9957798b68> in <module>
#       1 plt.figure(figsize=(15,10))
#       2 sns.set(style="darkgrid")
# ----> 3 ax1 = video_df.plot.scatter(x='Published Day Num', y='lViews', c = 'vader_compound', s= 'Comments Count tool', figsize = (15,10))
#       4 #ax.set_xticklabels([datetime.fromtimestamp(ts / 1e9).strftime('%H:%M:%S') for ts in ax.get_xticks()])
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     877             label = None
#     878         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
# --> 879                              label=label, cmap=cmap, **self.kwds)
#     880         if cb:
#     881             img = ax.collections[0]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4488                 offsets=offsets,
#    4489                 transOffset=kwargs.pop('transform', self.transData),
# -> 4490                 alpha=alpha
#    4491                 )
#    4492         collection.set_transform(mtransforms.IdentityTransform())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
# --> 885         self.set_sizes(sizes)
#     886         self.stale = True
#     887
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in set_sizes(self, sizes, dpi)
#     855             self._sizes = np.asarray(sizes)
#     856             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 857             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     858             self._transforms[:, 0, 0] = scale
#     859             self._transforms[:, 1, 1] = scale
#
# TypeError: ufunc 'sqrt' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
video_df = video_df.assign(vader_neg_prp=[i['neg'] for i in scorelst],
                vader_pos_prp = [i['pos'] for i in scorelst],
                vader_neut_prp = [i['neu'] for i in scorelst],
                vader_compound = [i['pos'] for i in scorelst])

# %%
video_df.to_csv('videos_full_info_sentiment.csv')

# %%
video_df = pd.read_csv('videos_full_info_sentiment.csv')
